# %%
# Final Data Analysis
# Discuss the steps you took to analyze the data and answer each question you asked in your proposal.
# Present and discuss interesting figures developed during analysis, ideally with the help of Jupyter Notebook.
# Discuss insights you had while exploring the data that you didn't anticipate.
# Discuss any problems that arose after exploring the data, and how you resolved them.
# Present and discuss interesting figures developed during exploration, ideally with the help of Jupyter Notebook.

# Discuss your findings. Did you find what you expected to find? If not, why not? What inferences or general conclusions can you draw from your analysis?

# %%
# Initialize imports
import csv 
import os
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import pylab
import seaborn as sns
# Add new library

# %matplotlib inline

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  'CVS_Pharmacy_USA_sample.csv',
#  'CVS_Walgreens.ipynb',
#  'Data Analysis.ipynb',
#  'drugs recalled from 2017-2022.csv',
#  'Medicare Part B Drug Spending and Utilization, Calendar Years 2012 - 2016.csv',
#  'medicare part b, generric and mannufacturer info.csv',
#  'Prescription_Drug_5_Year_History.csv',
#  'Walgreens_USA_sample.csv']

# %%
# Set .csv file paths & Import data
Recall_5yr = Path("drugs recalled from 2017-2022.csv")
History_5yr = Path("Prescription_Drug_5_Year_History.csv")
Medicare_Spending = Path("Medicare Part B Drug Spending and Utilization, Calendar Years 2012 - 2016.csv")
Medicare_Manufacturer = Path("medicare part b, generric and mannufacturer info.csv")

# %%
# Load CSV data into Pandas using read_csv/ Clean File & Headers
Recall_5yr_df = pd.read_csv(Recall_5yr).rename(columns={'Unnamed: 1': 'Brand Names','Unnamed: 2': 'Product Description'})
History_5yr_df = pd.read_csv(History_5yr)
Medicare_Manufacturer_df = pd.read_csv(Medicare_Manufacturer).rename(columns={'Unnamed: 1': 'Drug Description','Unnamed: 2': 'Brand Name',
                                                                              'Unnamed: 3': 'Generic Name','Unnamed: 4': 'Manufacturer'})
Medicare_Spending_df = pd.read_csv(Medicare_Spending)

# %%
Medicare_Spending_df = pd.read_csv(Medicare_Spending)
Medicare_Spending_df = Medicare_Spending_df.iloc[2:,:]
spending_header = Medicare_Spending_df.iloc[0]
Medicare_Spending_df = Medicare_Spending_df.iloc[1:,:]
Medicare_Spending_df.columns = spending_header
Medicare_Spending_df
# Out:
# 2   Medicare Billing Code (HCPCS Code)  \
# 3                                J0287
# 4                                J0401
# 5                                A9583
# 6                                J9264
# 7                                J0132
# ..                                 ...
# 474                              J9320
# 475                              Q5101
# 476                              J9202
# 477                              J7527
# 478                              J2358
#
# 2                                     Drug Description        Brand Name  \
# 3       Injection, amphotericin b lipid complex, 10 mg           Abelcet
# 4      Injection, aripiprazole, extended release, 1 mg  Abilify Maintena
# 5              Injection, gadofosveset trisodium, 1 ml           Ablavar
# 6    Injection, paclitaxel protein-bound particles,...          Abraxane
# 7                    Injection, acetylcysteine, 100 mg        Acetadote*
# ..                                                 ...               ...
# 474                    Injection, streptozocin, 1 gram           Zanosar
# 475  Injection, filgrastim (G-CSF), biosimilar, 1 m...            Zarxio
# 476              Goserelin acetate implant, per 3.6 mg           Zoladex
# 477                          Everolimus, oral, 0.25 mg          Zortress
# 478           Injection, olanzapine, long-acting, 1 mg  Zyprexa Relprevv
#
# 2                    Generic Name Total Spending Total Dosage Units  \
# 3    Amphotericin B Lipid Complex       $691,519             42,211
# 4                    Aripiprazole            NaN                NaN
# 5          Gadofosveset TrIsodium        $47,794              3,463
# 6        Paclitaxel Protein-Bound   $134,128,476         14,085,125
# 7                 Acetylcysteine*       $311,830            107,702
# ..                            ...            ...                ...
# 474                  Streptozocin       $234,870                866
# 475               Filgrastim-Sndz            NaN                NaN
# 476             Goserelin Acetate     $7,822,947             47,326
# 477                    Everolimus            NaN                NaN
# 478            Olanzapine Pamoate       $168,260             64,601
#
# 2   Total Claims Total Beneficiaries Average Spending Per Dosage Unit  \
# 3          1,265                 420                           $16.38
# 4            NaN                 NaN                              NaN
# 5            352                 346                           $13.80
# 6         60,473               8,392                            $9.52
# 7          1,874               1,748                            $2.90
# ..           ...                 ...                              ...
# 474          640                  61                          $271.21
# 475          NaN                 NaN                              NaN
# 476       18,784               6,539                          $165.30
# 477          NaN                 NaN                              NaN
# 478        1,084                 846                            $2.60
#
# 2   Average Spending Per Claim  ... Total Spending Total Dosage Units  \
# 3                      $546.66  ...       $278,320             16,682
# 4                          NaN  ...     $2,422,097            582,030
# 5                      $135.78  ...        $45,230              2,897
# 6                    $2,217.99  ...   $274,334,848         27,661,567
# 7                      $166.40  ...       $113,117             71,638
# ..                         ...  ...            ...                ...
# 474                    $366.98  ...       $158,808                511
# 475                        NaN  ...    $28,764,480         32,886,282
# 476                    $416.47  ...     $8,439,887             29,027
# 477                        NaN  ...    $32,138,786          4,307,784
# 478                    $155.22  ...       $189,893             66,126
#
# 2   Total Claims Total Beneficiaries Average Spending Per Dosage Unit  \
# 3            786                 250                           $16.68
# 4          1,996                 477                            $4.16
# 5            326                 325                           $15.61
# 6        115,988              17,380                            $9.92
# 7          1,542               1,060                            $1.58
# ..           ...                 ...                              ...
# 474          412                  36                          $310.78
# 475       69,711              10,390                            $0.87
# 476       12,632               3,863                          $290.76
# 477       13,743               1,887                            $7.46
# 478        1,306               1,052                            $2.87
#
# 2   Average Spending Per Claim Average Spending Per Beneficiary  \
# 3                      $354.10                        $1,113.28
# 4                    $1,213.48                        $5,077.77
# 5                      $138.74                          $139.17
# 6                    $2,365.20                       $15,784.51
# 7                       $73.36                          $106.71
# ..                         ...                              ...
# 474                    $385.46                        $4,411.34
# 475                    $412.62                        $2,768.48
# 476                    $668.14                        $2,184.80
# 477                  $2,338.56                       $17,031.68
# 478                    $145.40                          $180.51
#
# 2   Average Sales Price (ASP)  \
# 3                      $13.33
# 4                       $4.32
# 5                      $16.43
# 6                      $10.10
# 7                       $1.61
# ..                        ...
# 474                   $320.25
# 475                     $0.91
# 476                   $297.74
# 477                     $7.60
# 478                     $2.92
#
# 2   Change in Average Spending Per Dosage Unit (2015-2016)  \
# 3                                               14.24%
# 4                                                5.35%
# 5                                               17.66%
# 6                                                3.64%
# 7                                              -16.69%
# ..                                                 ...
# 474                                             -4.29%
# 475                                             -8.42%
# 476                                             15.29%
# 477                                              9.28%
# 478                                              2.29%
#
# 2   Annual Growth Rate in Average Spending Per Dosage Unit (2012-2016)
# 3                                                0.46%
# 4                                                5.48%
# 5                                                3.13%
# 6                                                1.02%
# 7                                              -14.06%
# ..                                                 ...
# 474                                              3.46%
# 475                                             -8.42%
# 476                                             15.16%
# 477                                              6.47%
# 478                                              2.47%
#
# [476 rows x 42 columns]

# %%
display (Recall_5yr_df)
# Out:
#     Recalls, Market Withdrawals, & Safety Alerts | FDA  \
# 0                                                 Date
# 1                                           11/05/2019
# 2                                           10/26/2019
# 3                                           10/30/2019
# 4                                           12/17/2019
# ..                                                 ...
# 160                                         04/07/2020
# 161                                         04/07/2020
# 162                                         04/07/2020
# 163                                         03/19/2020
# 164                                         03/31/2021
#
#                           Brand Names  \
# 0                         Brand-Names
# 1                            Viatrexx
# 2          Mylan Pharmaceuticals Inc.
# 3                   ICU Medical, Inc.
# 4     No Brand name Listed on Package
# ..                                ...
# 160         PASTA DE LASSAR ANDROMACO
# 161         PASTA DE LASSAR ANDROMACO
# 162                AMA Wholesale Inc.
# 163        CVS, Rhinall, Humist, more
# 164  Thumbs Up 7, Shogun, Krazy Night
#
#                                    Product Description
# 0                                  Product-Description
# 1                          Sterile injectable products
# 2                  Alprazolam Tablets, USP C-IV 0.5 mg
# 3    Lactated Ringer's Injection, USP and 0.9% Sodi...
# 4    Bull Platinum 30000, Stallion Platinum 30000, ...
# ..                                                 ...
# 160          Pasta De Lassar Andromaco Skin Protectant
# 161          Pasta De Lassar Andromaco Skin Protectant
# 162                    Rhino 69 Extreme 50000 capsules
# 163                  Nasal Products and Baby Oral Gels
# 164     Dietary Supplement for male sexual enhancement
#
# [165 rows x 3 columns]

# %%
# Recall_5yr: Count nulls
Recall_5yr_df.isna().sum()
# Out:
# Recalls, Market Withdrawals, & Safety Alerts | FDA    0
# Brand Names                                           0
# Product Description                                   0
# dtype: int64

# %%
display (History_5yr_df)
# Out:
#        Manufacturer Name   NDC Number Effective Date History Effective Date  \
# 0                 AbbVie     32120370     01/14/2022             12/22/2017
# 1                 AbbVie     32120370     01/14/2022             01/01/2019
# 2                 AbbVie     32120370     01/14/2022             01/01/2020
# 3                 AbbVie     32120370     01/14/2022             01/01/2021
# 4                 AbbVie     32120370     01/14/2022             01/14/2022
# ...                  ...          ...            ...                    ...
# 3585  Zyla Life Sciences  69344021311     02/01/2022             01/01/2018
# 3586  Zyla Life Sciences  69344021311     02/01/2022             01/01/2019
# 3587  Zyla Life Sciences  69344021311     02/01/2022             01/01/2020
# 3588  Zyla Life Sciences  69344021311     02/01/2022             04/01/2021
# 3589  Zyla Life Sciences  69344021311     02/01/2022             02/01/2022
#
#      WAC Increase Amount WAC Amount
# 0                  $5.59     $86.62
# 1                  $5.37     $91.99
# 2                  $6.81     $98.80
# 3                  $6.13    $104.93
# 4                  $6.50    $111.43
# ...                  ...        ...
# 3585              $90.19  $1,001.19
# 3586              $99.12  $1,100.31
# 3587             $108.93  $1,209.24
# 3588             $119.71  $1,328.95
# 3589             $131.57  $1,460.52
#
# [3590 rows x 6 columns]

# %%
# History_5yr: Count nulls
History_5yr_df.isna().sum()
# Out:
# Manufacturer Name         0
# NDC Number                0
# Effective Date            0
# History Effective Date    0
# WAC Increase Amount       0
# WAC Amount                0
# dtype: int64

# %%
display(Medicare_Manufacturer_df)
# Out:
#      Medicare Part B Brand, Generic and Manufacturer Information  \
# 0                                                   NaN
# 1                    Medicare Billing Code (HCPCS Code)
# 2                                                 90371
# 3                                                 90371
# 4                                                 90375
# ...                                                 ...
# 1507                                              Q9967
# 1508                                              Q9967
# 1509                                              Q9967
# 1510                                              Q9967
# 1511                                              Q9967
#
#                                        Drug Description      Brand Name  \
# 0                                                   NaN             NaN
# 1                                      Drug Description      Brand Name
# 2     Hepatitis B immune globulin for injection into...  HyperHEP B S-D
# 3     Hepatitis B immune globulin for injection into...         Nabi-Hb
# 4     Rabies immune globulin for injection beneath t...    HyperRAB S-D
# ...                                                 ...             ...
# 1507  Low osmolar contrast material, 300-399 mg/ml i...     Optiray 350
# 1508  Low osmolar contrast material, 300-399 mg/ml i...      Oxilan-350
# 1509  Low osmolar contrast material, 300-399 mg/ml i...       Ultravist
# 1510  Low osmolar contrast material, 300-399 mg/ml i...       Visipaque
# 1511  Low osmolar contrast material, 300-399 mg/ml i...       Visipaque
#
#                      Generic Name     Manufacturer
# 0                             NaN              NaN
# 1                    Generic Name     Manufacturer
# 2     Hepatitis B Immune Globulin  Grifols Therape
# 3     Hepatitis B Immune Globulin    Biotest Pharm
# 4       Rabies Immune Globulin/PF  Grifols Therape
# ...                           ...              ...
# 1507                     Ioversol  Mallinckrodt SP
# 1508                      Ioxilan      Guerbet LLC
# 1509                    Iopromide  Bayer,Pharm Div
# 1510                    Iodixanol  GE Health/Nova+
# 1511                    Iodixanol    GE Healthcare
#
# [1512 rows x 5 columns]

# %%
# Medicare_Manufacturer_df: Count nulls
Medicare_Manufacturer_df.isna().sum()
# Out:
# Medicare Part B Brand, Generic and Manufacturer Information     1
# Drug Description                                                1
# Brand Name                                                     33
# Generic Name                                                   33
# Manufacturer                                                   33
# dtype: int64

# %%
display(Medicare_Spending_df)
# Out:
# 2   Medicare Billing Code (HCPCS Code)  \
# 3                                J0287
# 4                                J0401
# 5                                A9583
# 6                                J9264
# 7                                J0132
# ..                                 ...
# 474                              J9320
# 475                              Q5101
# 476                              J9202
# 477                              J7527
# 478                              J2358
#
# 2                                     Drug Description        Brand Name  \
# 3       Injection, amphotericin b lipid complex, 10 mg           Abelcet
# 4      Injection, aripiprazole, extended release, 1 mg  Abilify Maintena
# 5              Injection, gadofosveset trisodium, 1 ml           Ablavar
# 6    Injection, paclitaxel protein-bound particles,...          Abraxane
# 7                    Injection, acetylcysteine, 100 mg        Acetadote*
# ..                                                 ...               ...
# 474                    Injection, streptozocin, 1 gram           Zanosar
# 475  Injection, filgrastim (G-CSF), biosimilar, 1 m...            Zarxio
# 476              Goserelin acetate implant, per 3.6 mg           Zoladex
# 477                          Everolimus, oral, 0.25 mg          Zortress
# 478           Injection, olanzapine, long-acting, 1 mg  Zyprexa Relprevv
#
# 2                    Generic Name Total Spending Total Dosage Units  \
# 3    Amphotericin B Lipid Complex       $691,519             42,211
# 4                    Aripiprazole            NaN                NaN
# 5          Gadofosveset TrIsodium        $47,794              3,463
# 6        Paclitaxel Protein-Bound   $134,128,476         14,085,125
# 7                 Acetylcysteine*       $311,830            107,702
# ..                            ...            ...                ...
# 474                  Streptozocin       $234,870                866
# 475               Filgrastim-Sndz            NaN                NaN
# 476             Goserelin Acetate     $7,822,947             47,326
# 477                    Everolimus            NaN                NaN
# 478            Olanzapine Pamoate       $168,260             64,601
#
# 2   Total Claims Total Beneficiaries Average Spending Per Dosage Unit  \
# 3          1,265                 420                           $16.38
# 4            NaN                 NaN                              NaN
# 5            352                 346                           $13.80
# 6         60,473               8,392                            $9.52
# 7          1,874               1,748                            $2.90
# ..           ...                 ...                              ...
# 474          640                  61                          $271.21
# 475          NaN                 NaN                              NaN
# 476       18,784               6,539                          $165.30
# 477          NaN                 NaN                              NaN
# 478        1,084                 846                            $2.60
#
# 2   Average Spending Per Claim  ... Total Spending Total Dosage Units  \
# 3                      $546.66  ...       $278,320             16,682
# 4                          NaN  ...     $2,422,097            582,030
# 5                      $135.78  ...        $45,230              2,897
# 6                    $2,217.99  ...   $274,334,848         27,661,567
# 7                      $166.40  ...       $113,117             71,638
# ..                         ...  ...            ...                ...
# 474                    $366.98  ...       $158,808                511
# 475                        NaN  ...    $28,764,480         32,886,282
# 476                    $416.47  ...     $8,439,887             29,027
# 477                        NaN  ...    $32,138,786          4,307,784
# 478                    $155.22  ...       $189,893             66,126
#
# 2   Total Claims Total Beneficiaries Average Spending Per Dosage Unit  \
# 3            786                 250                           $16.68
# 4          1,996                 477                            $4.16
# 5            326                 325                           $15.61
# 6        115,988              17,380                            $9.92
# 7          1,542               1,060                            $1.58
# ..           ...                 ...                              ...
# 474          412                  36                          $310.78
# 475       69,711              10,390                            $0.87
# 476       12,632               3,863                          $290.76
# 477       13,743               1,887                            $7.46
# 478        1,306               1,052                            $2.87
#
# 2   Average Spending Per Claim Average Spending Per Beneficiary  \
# 3                      $354.10                        $1,113.28
# 4                    $1,213.48                        $5,077.77
# 5                      $138.74                          $139.17
# 6                    $2,365.20                       $15,784.51
# 7                       $73.36                          $106.71
# ..                         ...                              ...
# 474                    $385.46                        $4,411.34
# 475                    $412.62                        $2,768.48
# 476                    $668.14                        $2,184.80
# 477                  $2,338.56                       $17,031.68
# 478                    $145.40                          $180.51
#
# 2   Average Sales Price (ASP)  \
# 3                      $13.33
# 4                       $4.32
# 5                      $16.43
# 6                      $10.10
# 7                       $1.61
# ..                        ...
# 474                   $320.25
# 475                     $0.91
# 476                   $297.74
# 477                     $7.60
# 478                     $2.92
#
# 2   Change in Average Spending Per Dosage Unit (2015-2016)  \
# 3                                               14.24%
# 4                                                5.35%
# 5                                               17.66%
# 6                                                3.64%
# 7                                              -16.69%
# ..                                                 ...
# 474                                             -4.29%
# 475                                             -8.42%
# 476                                             15.29%
# 477                                              9.28%
# 478                                              2.29%
#
# 2   Annual Growth Rate in Average Spending Per Dosage Unit (2012-2016)
# 3                                                0.46%
# 4                                                5.48%
# 5                                                3.13%
# 6                                                1.02%
# 7                                              -14.06%
# ..                                                 ...
# 474                                              3.46%
# 475                                             -8.42%
# 476                                             15.16%
# 477                                              6.47%
# 478                                              2.47%
#
# [476 rows x 42 columns]

# %%
# Medicare_Spending_df: Count nulls
Medicare_Spending_df.isna().sum()
# Out:
# 2
# Medicare Billing Code (HCPCS Code)                                     0
# Drug Description                                                       0
# Brand Name                                                             0
# Generic Name                                                          32
# Total Spending                                                        47
# Total Dosage Units                                                    47
# Total Claims                                                          47
# Total Beneficiaries                                                   50
# Average Spending Per Dosage Unit                                      47
# Average Spending Per Claim                                            47
# Average Spending Per Beneficiary                                      50
# Total Spending                                                        35
# Total Dosage Units                                                    35
# Total Claims                                                          35
# Total Beneficiaries                                                   37
# Average Spending Per Dosage Unit                                      35
# Average Spending Per Claim                                            35
# Average Spending Per Beneficiary                                      37
# Total Spending                                                        15
# Total Dosage Units                                                    15
# Total Claims                                                          15
# Total Beneficiaries                                                   16
# Average Spending Per Dosage Unit                                      15
# Average Spending Per Claim                                            15
# Average Spending Per Beneficiary                                      16
# Total Spending                                                         0
# Total Dosage Units                                                     0
# Total Claims                                                           0
# Total Beneficiaries                                                    4
# Average Spending Per Dosage Unit                                       0
# Average Spending Per Claim                                             0
# Average Spending Per Beneficiary                                       4
# Total Spending                                                         0
# Total Dosage Units                                                     0
# Total Claims                                                           0
# Total Beneficiaries                                                    2
# Average Spending Per Dosage Unit                                       0
# Average Spending Per Claim                                             0
# Average Spending Per Beneficiary                                       2
# Average Sales Price (ASP)                                              0
# Change in Average Spending Per Dosage Unit (2015-2016)                 0
# Annual Growth Rate in Average Spending Per Dosage Unit (2012-2016)     0
# dtype: int64

# %%
# Drop nulls (For All)
Recall_5yr_df = Recall_5yr_df.dropna()
History_5yr_df = History_5yr_df.dropna()
Medicare_Manufacturer_df = History_5yr_df.dropna()
Medicare_Spending_df = Medicare_Spending_df.dropna()

# %%
# Cleanup Verification
Medicare_Manufacturer_df.isna().sum()
# Out:
# Manufacturer Name         0
# NDC Number                0
# Effective Date            0
# History Effective Date    0
# WAC Increase Amount       0
# WAC Amount                0
# dtype: int64

# %%
# Cleanup Verification
Medicare_Spending_df.isna().sum()
# Out:
# 2
# Medicare Billing Code (HCPCS Code)                                    0
# Drug Description                                                      0
# Brand Name                                                            0
# Generic Name                                                          0
# Total Spending                                                        0
# Total Dosage Units                                                    0
# Total Claims                                                          0
# Total Beneficiaries                                                   0
# Average Spending Per Dosage Unit                                      0
# Average Spending Per Claim                                            0
# Average Spending Per Beneficiary                                      0
# Total Spending                                                        0
# Total Dosage Units                                                    0
# Total Claims                                                          0
# Total Beneficiaries                                                   0
# Average Spending Per Dosage Unit                                      0
# Average Spending Per Claim                                            0
# Average Spending Per Beneficiary                                      0
# Total Spending                                                        0
# Total Dosage Units                                                    0
# Total Claims                                                          0
# Total Beneficiaries                                                   0
# Average Spending Per Dosage Unit                                      0
# Average Spending Per Claim                                            0
# Average Spending Per Beneficiary                                      0
# Total Spending                                                        0
# Total Dosage Units                                                    0
# Total Claims                                                          0
# Total Beneficiaries                                                   0
# Average Spending Per Dosage Unit                                      0
# Average Spending Per Claim                                            0
# Average Spending Per Beneficiary                                      0
# Total Spending                                                        0
# Total Dosage Units                                                    0
# Total Claims                                                          0
# Total Beneficiaries                                                   0
# Average Spending Per Dosage Unit                                      0
# Average Spending Per Claim                                            0
# Average Spending Per Beneficiary                                      0
# Average Sales Price (ASP)                                             0
# Change in Average Spending Per Dosage Unit (2015-2016)                0
# Annual Growth Rate in Average Spending Per Dosage Unit (2012-2016)    0
# dtype: int64

# %%
display(Medicare_Spending_df)
# Out:
# 2   Medicare Billing Code (HCPCS Code)  \
# 3                                J0287
# 5                                A9583
# 6                                J9264
# 7                                J0132
# 8                                J7608
# ..                                 ...
# 471                              J7185
# 472                              J9228
# 474                              J9320
# 476                              J9202
# 478                              J2358
#
# 2                                     Drug Description        Brand Name  \
# 3       Injection, amphotericin b lipid complex, 10 mg           Abelcet
# 5              Injection, gadofosveset trisodium, 1 ml           Ablavar
# 6    Injection, paclitaxel protein-bound particles,...          Abraxane
# 7                    Injection, acetylcysteine, 100 mg        Acetadote*
# 8    Acetylcysteine, inhalation solution, fda-appro...    Acetylcysteine
# ..                                                 ...               ...
# 471  Injection, factor viii (antihemophilic factor,...           Xyntha*
# 472                        Injection, ipilimumab, 1 mg            Yervoy
# 474                    Injection, streptozocin, 1 gram           Zanosar
# 476              Goserelin acetate implant, per 3.6 mg           Zoladex
# 478           Injection, olanzapine, long-acting, 1 mg  Zyprexa Relprevv
#
# 2                      Generic Name Total Spending Total Dosage Units  \
# 3      Amphotericin B Lipid Complex       $691,519             42,211
# 5            Gadofosveset TrIsodium        $47,794              3,463
# 6          Paclitaxel Protein-Bound   $134,128,476         14,085,125
# 7                   Acetylcysteine*       $311,830            107,702
# 8                    Acetylcysteine     $1,025,456            448,775
# ..                              ...            ...                ...
# 471  Antihemoph.FVIII,b-Domain Del*    $12,541,162            355,628
# 472                      Ipilimumab   $193,989,380          1,551,476
# 474                    Streptozocin       $234,870                866
# 476               Goserelin Acetate     $7,822,947             47,326
# 478              Olanzapine Pamoate       $168,260             64,601
#
# 2   Total Claims Total Beneficiaries Average Spending Per Dosage Unit  \
# 3          1,265                 420                           $16.38
# 5            352                 346                           $13.80
# 6         60,473               8,392                            $9.52
# 7          1,874               1,748                            $2.90
# 8         19,356               6,559                            $2.29
# ..           ...                 ...                              ...
# 471          444                  55                           $35.26
# 472        6,126               2,101                          $125.04
# 474          640                  61                          $271.21
# 476       18,784               6,539                          $165.30
# 478        1,084                 846                            $2.60
#
# 2   Average Spending Per Claim  ... Total Spending Total Dosage Units  \
# 3                      $546.66  ...       $278,320             16,682
# 5                      $135.78  ...        $45,230              2,897
# 6                    $2,217.99  ...   $274,334,848         27,661,567
# 7                      $166.40  ...       $113,117             71,638
# 8                       $52.98  ...     $1,392,097            379,998
# ..                         ...  ...            ...                ...
# 471                 $28,245.86  ...    $15,275,680            689,507
# 472                 $31,666.57  ...   $236,636,118          1,746,044
# 474                    $366.98  ...       $158,808                511
# 476                    $416.47  ...     $8,439,887             29,027
# 478                    $155.22  ...       $189,893             66,126
#
# 2   Total Claims Total Beneficiaries Average Spending Per Dosage Unit  \
# 3            786                 250                           $16.68
# 5            326                 325                           $15.61
# 6        115,988              17,380                            $9.92
# 7          1,542               1,060                            $1.58
# 8         14,130               4,460                            $3.66
# ..           ...                 ...                              ...
# 471          754                  72                           $22.15
# 472        6,151               2,239                          $135.53
# 474          412                  36                          $310.78
# 476       12,632               3,863                          $290.76
# 478        1,306               1,052                            $2.87
#
# 2   Average Spending Per Claim Average Spending Per Beneficiary  \
# 3                      $354.10                        $1,113.28
# 5                      $138.74                          $139.17
# 6                    $2,365.20                       $15,784.51
# 7                       $73.36                          $106.71
# 8                       $98.52                          $312.13
# ..                         ...                              ...
# 471                 $20,259.52                      $212,162.22
# 472                 $38,471.16                      $105,688.31
# 474                    $385.46                        $4,411.34
# 476                    $668.14                        $2,184.80
# 478                    $145.40                          $180.51
#
# 2   Average Sales Price (ASP)  \
# 3                      $13.33
# 5                      $16.43
# 6                      $10.10
# 7                       $1.61
# 8                       $4.71
# ..                        ...
# 471                     $1.22
# 472                   $140.82
# 474                   $320.25
# 476                   $297.74
# 478                     $2.92
#
# 2   Change in Average Spending Per Dosage Unit (2015-2016)  \
# 3                                               14.24%
# 5                                               17.66%
# 6                                                3.64%
# 7                                              -16.69%
# 8                                                2.00%
# ..                                                 ...
# 471                                            -36.96%
# 472                                              1.65%
# 474                                             -4.29%
# 476                                             15.29%
# 478                                              2.29%
#
# 2   Annual Growth Rate in Average Spending Per Dosage Unit (2012-2016)
# 3                                                0.46%
# 5                                                3.13%
# 6                                                1.02%
# 7                                              -14.06%
# 8                                               12.53%
# ..                                                 ...
# 471                                            -10.97%
# 472                                              2.03%
# 474                                              3.46%
# 476                                             15.16%
# 478                                              2.47%
#
# [404 rows x 42 columns]

# %%
# Create a numerical aggregation by grouping the data by year and averaging the results
price_increase_df =(Medicare_Spending_df[["Brand Name","Total Spending"]]
    .groupby("Brand Name")
    .mean("Total Spending")
#    .sort_values(index=1)
)

price_increase_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [Abelcet, Ablavar, Abraxane, Acetadote*, Acetylcysteine, Actemra, Activase*, Acyclovir Sodium, Adacel Tdap*, Adrenalin*, Adrucil*, Advate*, Albuterol Sulfate (J7611), Albuterol Sulfate (J7613), Alimta, Alkeran (J8600), Alkeran (J9245)*, Aloxi, Alphanate (J7186), Alphanate (J7190)*, Alphanine SD*, AmbIsome, Amifostine, Amikacin Sulfate, Aminophylline, Amphotericin B, Ampicillin Sodium, Ampicillin-Sulbactam*, Angiomax*, Anzemet, Apligraf, Aralast NP*, Aranesp (J0881), Aranesp (J0882), Aristospan, Arixtra*, Arzerra, Ativan*, Atropine Sulfate, Avastin, Azacitidine*, Azasan*, Azithromycin*, BCG (Tice Strain) (90585)*, BCG (Tice Strain) (90586)*, BCG (Tice Strain) (J9031)*, Bebulin*, Benefix, Benlysta, Bentyl, Benztropine Mesylate*, Berinert, Betamethasone Acetate-Sod Phos*, Bethkis*, Bicillin C-R, Bicillin L-A, Bicnu, Bleomycin Sulfate, Boniva*, Botox*, Brovana, Budesonide*, Buprenorphine HCL, Busulfex, Butorphanol Tartrate, COsmegen, Calcitriol, Calcium DIsodium Versenate, Calcium Folinate*, Calcium Gluconate, Camptosar*, Cancidas, Capecitabine (J8520)*, Capecitabine (J8521)*, Carboplatin, Carimune NF Nanofiltered*, Carnitor*, Cefazolin Sodium*, Cefepime*, Cefotaxime Sodium*, Cefoxitin*, Ceftazidime*, Ceftriaxone*, Cefuroxime*, Cellcept*, Cerezyme, Chirhostim, Chloramphenicol Sod Succinate, Chlorothiazide Sodium*, Chlorpromazine HCL, Cholografin Meglumine*, Chorionic Gonadotropin*, Cidofovir*, Cinryze, Cipro I.V.*, Cisplatin, Cladribine, Clolar, Clonidine HCL*, Colistimethate*, ...]
#
# [404 rows x 0 columns]

# %%
# Bar plot of the daily standard deviations
price_increases.plot.bar(title='Total Spending By Brand Name')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 2>()
#       1 # Bar plot of the daily standard deviations
# ----> 2 price_increases.plot.bar(title='Total Spending By Brand Name')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1131, in PlotAccessor.bar(self, x, y, **kwargs)
#    1043 @Appender(
#    1044     """
#    1045     See Also
#    (...)
#    1120 @Appender(_bar_or_line_doc)
#    1121 def bar(self, x=None, y=None, **kwargs):
#    1122     """
#    1123     Vertical bar plot.
#    1124
#    (...)
#    1129     other axis represents a measured value.
#    1130     """
# -> 1131     return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:327, in MPLPlot.generate(self)
#     325 def generate(self):
#     326     self._args_adjust()
# --> 327     self._compute_plot_data()
#     328     self._setup_subplots()
#     329     self._make_plot()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:506, in MPLPlot._compute_plot_data(self)
#     504 # no non-numeric frames or series allowed
#     505 if is_empty:
# --> 506     raise TypeError("no numeric data to plot")
#     508 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
# Performance Analysis- Cumulative returns of all portfolios
cumulative_return = (1+Medicare_Spending_df).cumprod()
cumulative_return.plot(title='Cumulative Returns', figsize=(20,15));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\roperator.py:9, in radd(left, right)
#       8 def radd(left, right):
# ----> 9     return right + left
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 # Performance Analysis- Cumulative returns of all portfolios
# ----> 2 cumulative_return = (1+Medicare_Spending_df).cumprod()
#       3 cumulative_return.plot(title='Cumulative Returns', figsize=(20,15))
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:104, in OpsMixin.__radd__(self, other)
#     102 @unpack_zerodim_and_defer("__radd__")
#     103 def __radd__(self, other):
# --> 104     return self._arith_method(other, roperator.radd)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6946, in DataFrame._arith_method(self, other, op)
#    6942 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6944 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
# -> 6946 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6947 return self._construct_result(new_data)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6973, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    6970 if not is_list_like(right):
#    6971     # i.e. scalar, faster than checking np.ndim(right) == 0
#    6972     with np.errstate(all="ignore"):
# -> 6973         bm = self._mgr.apply(array_op, right=right)
#    6974     return self._constructor(bm)
#    6976 elif isinstance(right, DataFrame):
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:302, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     300 try:
#     301     if callable(f):
# --> 302         applied = b.apply(f, **kwargs)
#     303     else:
#     304         applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402, in Block.apply(self, func, **kwargs)
#     396 @final
#     397 def apply(self, func, **kwargs) -> list[Block]:
#     398     """
#     399     apply the function to my values; return a block if we are not
#     400     one
#     401     """
# --> 402     result = func(self.values, **kwargs)
#     404     return self._split_op_result(result)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:222, in arithmetic_op(left, right, op)
#     217 else:
#     218     # TODO we should handle EAs consistently and move this check before the if/else
#     219     # (https://github.com/pandas-dev/pandas/issues/41165)
#     220     _bool_arith_check(op, left, right)
# --> 222     res_values = _na_arithmetic_op(left, right, op)
#     224 return res_values
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:170, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 except TypeError:
#     165     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     166         # For object dtype, fallback to a masked operation (only operating
#     167         #  on the non-missing values)
#     168         # Don't do this for comparisons, as that will handle complex numbers
#     169         #  incorrectly, see GH#32047
# --> 170         result = _masked_arith_op(left, right, op)
#     171     else:
#     172         raise
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:127, in _masked_arith_op(x, y, op)
#     124         mask = np.where(y == 1, False, mask)
#     126     if mask.any():
# --> 127         result[mask] = op(xrav[mask], y)
#     129 np.putmask(result, ~mask, np.nan)
#     130 result = result.reshape(x.shape)  # 2D compat
#
# File ~\anaconda3\lib\site-packages\pandas\core\roperator.py:9, in radd(left, right)
#       8 def radd(left, right):
# ----> 9     return right + left
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
